# %% [markdown]
# ## 笔试题说明
#
# - 直接在标注 `# 修改这部分代码完成需求` 的格子里修改代码，实现题目中描述的功能
# - 标注 `# 这里是测试代码` 的格子仅用于测试，无需修改
# - 代码尽量简洁高效（例如：可使用匿名函数、函数式编程等，减少不必要的变量、函数或循环）
# - 1-3题的解决方案应具备通用性，而不是只适用于测试代码中的个例
# - 代码需确保其在`Jupyter Notebook`环境中能正常运行（如果在别处写的代码粘贴过来，注意格式等问题）

# %% [markdown]
# -----
# <center><b>------这里是华丽的分界线，以下进入正式答题部分------</b></center>
#
# -----

# %% [markdown]
# ### 1. 字符串操作——命名方式转换

# %% [markdown]
# 把下划线命名（也叫蛇形命名，所有单词都是小写，中间通过下划线连接），转化为小驼峰命名法（第一个单词小写，其余所有单词首字母大写）。
# 例如`'go_to_next_page'`，转化后改写为`'goToNextPage'`。
# 请用两种方法实现：
# - 一种方法为正则表达式替换方法，即`re.sub()`
# - 另一种方法不限

# %%
# 修改这部分代码完成需求
import re
def convert_name_re(name):
    # 方法一（正则）：
    pass

def convert_name(name):
    # 方法二（其他）：
    pass

# %%
# 这里是测试代码
print(convert_name_re('go_to_next_page'))  # 'goToNextPage'
print(convert_name_re('crawl_home_site'))  # 'crawlHomeSite'
print(convert_name('go_to_next_page'))  # 'goToNextPage'
print(convert_name('crawl_home_site'))  # 'crawlHomeSite'

# %% [markdown]
# ### 2. 设计模式——装饰器

# %% [markdown]
# 编写一个装饰器函数`log_time`，被装饰的函数执行时打印出【函数名】与【执行时间】（时间单位为秒，只需保留小数点后一位，见测试示例）。
# 注：装饰器函数要具备通用性，即被装饰函数允许传入位置参数与关键字参数。

# %%
# 修改这部分代码完成需求
import time
def log_time(func):
    pass

# %%
# 这里是测试代码
@log_time
def salute(word):
    time.sleep(2)
    print(word)

salute('hello') # ’hello‘ ’Function [saySomething] took 2.0 seconds to execute‘

# %% [markdown]
# ### 3. 面向对象——运算符重载

# %% [markdown]
# 定义一个Vector类，能够实现任意维向量的加法运算（类似numpy中的向量运算）。
# 例如，测试代码中分别针对三维向量和二维向量的加法运算：
# $ (1,3,6) + (2,4,3) = (3,7,9)  $
# $ (1,3) + (4,1) = (5,4)  $
# 提示：重写python内置的魔法方法 `__add__`和`__repr__`

# %%
# 修改这部分代码完成需求
class Vector:
    pass

# %%
# 这里是测试代码
A = Vector(1,3,6)
print(A) # (1,3,6)
B = Vector(2,4,3)
C = A + B
print(C) # (3,7,9)
print(Vector(1,3) + Vector(4,1)) # (5,4)

# %% [markdown]
# ### 4. 常规爬虫——模板解析

# %% [markdown]
# 采集“[新浪天气](http://weather.sina.com.cn/)”中的"逐月气候"(页面右下角)数据，包含1月-12月的每月降水量、最低气温、最高气温。

# %% [markdown]
# 把采集到的降水量和气温数据保存为形如以下结构的列表中：
# ```
# climate = [
#     {'month': 1,
#      'precipitaion': 50.6,
#      'temp_low': 1.1,
#      'temp_high': 8
#     },
#      ...
# ]
# ```
# 对于默认城市上海，这里只列出了一月的数据作为示例，即降水量为50.6(mm), 最低气温1.1(℃)，最高气温8(℃)。（都保留纯数字，不需要单位）

# %%
# 修改这部分代码完成需求
import requests
from lxml import etree
def get_climate():
    url = 'http://weather.sina.com.cn/'
    pass

# %%
# 这里是测试代码
print(get_climate())

# %% [markdown]
# ### 5. 验证码——背景噪音+汉字

# %% [markdown]
# 针对某个有反爬的网站详情页（[页面示例](http://cprp.nmpa.gov.cn/sfda/ShowJSYQAction.do?PID=b5cc9e51605b3e784396baf2b32d74f8)）中的汉字图片验证码（[验证码示例](http://cprp.nmpa.gov.cn/captcha.svl)），应当如何破解？
# - 实现过程尽量具体，例如：
#     - 写出实现二值化、降噪或截取图片的代码，比单纯写“图像二值化”、“降噪处理”、“截取图片的最小单元”这种描述更具体
# - 本问题为开放问题，给出中间过程或解决思路均可作为加分项
#     - 鼓励原创的思路，同时也允许使用开源的库、第三方工具等
# - 如果借助了第三方工具或平台，请根据自己的理解，简要介绍其原理和实现的功能
#     - 如：某个API通过XX方法对图片进行XX处理，从而消除了XX因素对于XX环节的影响
#
# 提示：可以多刷新几次图片寻找规律

# %%
# 修改这部分代码完成需求
import requests
from PIL import Image

def break_captcha(img):
    # 对于传入的图片进行验证码破解
    pass
    return {'x': '{}-{}-{}-', 'y': '{}-{}-{}-'}

# %% [markdown]
# （如果完成部分环节，这里可以描述后续解决思路）

# %%
# 这里是测试代码
from io import BytesIO
from requests import request
from matplotlib.pyplot import imshow
from PIL import Image
def get_test_image():
    url = 'http://cprp.nmpa.gov.cn/captcha.svl'
    res = request('GET', url, headers={'User-Agent': 'Mozilla/5.0'})
    return Image.open(BytesIO(res.content))

test_image = get_test_image() # 获取测试图片
imshow(test_image)  # 展示测试图片
break_captcha(test_image)  # 破解验证码，依次显示所需点击的三个汉字的坐标位置，如 {x: '150-106-172-', y: '106-58-60-''}
# Out:
# {'x': '{}-{}-{}-', 'y': '{}-{}-{}-'}

# %% [markdown]
# ### 6. 自由表达

# %% [markdown]
# 根据自己的相关经验与思考，畅所欲言，字数不限。可以参照，但不需要涵盖、也不用局限于以下几个方面。（我们希望团队成员在完成工作需求之余，也能有自己的总结和想法）
# - 工作感受
#     - 对于【爬虫开发工程师】这一职位的理解
#     - 遇到过哪些挑战，踩过哪些坑
#     - 有过哪些成就感或挫败感
#     - 最享受和最反感的工作内容或工作方式
# - 职业发展
#     - 未来最希望在哪些方面得到更多锻炼和提升
#     - 爬虫开发之外其他方面的能力
#     - 中长期（3-5年内）是否考虑转换到其他职位
# - 反馈或建议（针对这份面试题）
#     - 题目数量和用时是否合理
#     - 能否客观反映你的技术、知识、思维等
#     - 有没有表述不够清晰、严谨、有歧义的地方
#     - 是否有建议增加或去掉的问题
# - 其他
#     - 其他任何能为自己加分的技能、经历、个人项目等均可

# %% [markdown]
# (这里是留给小伙伴自由表达的地方，请直接修改)

# %% [markdown]
# -----
# <center><b>------这里是华丽的分界线，答题部分到此结束------</b></center>
#
# -----

# %% [markdown]
# <b>完成后保存此 `.ipynb` 文件并重命名为 `{姓名}-{职位}.ipynb` 文件（如：`雷军-爬虫开发.ipynb`），发送到HR小姐姐的邮箱 [suxiaoyu@dtcj.com](suxiaoyu@dtcj.com)</b>
# 我们将在提交后的1-3个工作日内，邀请能力匹配的申请者参加现场面试。
# 无论结果如何，希望你能在这个过程中有所收获，也希望我们能有一起合作的机会。
# <div style="margin-bottom: 100px"></div>
